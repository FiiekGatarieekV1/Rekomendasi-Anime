# %% [markdown]
# ### Import Library

# %%
# ---- Imports ----
from bs4 import BeautifulSoup   # pip install bs4
import json                     # pip install json
import numpy as np              # pip install numpy
import pandas as pd             # pip install pandas
import re                       # pip install re
import requests                 # pip install requests
import time                     # pip install time

# ---- Settings ----
pd.set_option('display.max_columns', None)

# ---- Constants ----
DATASETS_PATH = ('./datasets')

TRIES_LIMIT = (3)

# ANIME_IDS = (np.arange(0, 60000)) # all animes
# USER_IDS = (np.arange(0, 1030000)) # all users

ANIME_IDS = (np.arange(0, 200)) # sample animes
USER_IDS = (np.arange(0, 200)) # sample users

STATUS_CODE = (7)
BATCH_SIZE = (250) # number of users to fetch in each batch
MIN_DELAY_SECONDS = (60)
MAX_DELAY_SECONDS = (90)

# %% [markdown]
# ### Anime Data Fetcher

# %%
# ---- Dataset Structure ----
header = [
    'MAL_ID','Name', 'English_name', 'Japanese_name', 'Score',
    'Type', 'Episodes', 'Aired', 'Premiered', 'Status',
    'Producers', 'Licensors', 'Studios', 'Source', 'Duration', 'Rating',
    'Rank', 'Popularity', 'Favorites', 'Members', 'Watching',
    'Completed', 'On_hold', 'Dropped', 'Plan_to_watch', 'Scored_by',  'Score_1',
    'Score_2', 'Score_3', 'Score_4', 'Score_5', 'Score_6', 'Score_7', 'Score_8',
    'Score_9', 'Score_10'
]
full_anime_df = pd.DataFrame(columns=header)
full_anime_df

# ---- API Requisitions ----
for anime_id in ANIME_IDS:
    anime_api_url = f'https://api.jikan.moe/v4/anime/{anime_id}'
    statistics_api_url = f'https://api.jikan.moe/v4/anime/{anime_id}/statistics'
    anime_page = None
    statistics_page = None

    tries = 0
    while tries < TRIES_LIMIT:
        tries += 1
        anime_page = requests.get(anime_api_url)
        statistics_page = requests.get(statistics_api_url)
        
        if anime_page.status_code == 200 and statistics_page.status_code == 200: break
        time.sleep(2)
    
    # if the requisition successfully returned the anime data, it will be processed
    if anime_page.status_code == 200 and statistics_page.status_code == 200:
        anime_json_data = anime_page.json()
        statistics_json_data = statistics_page.json()
    
        # if 'data' property is present, it's formatted and inserted into the dataset
        if 'data' in anime_json_data and 'data' in statistics_json_data:
            anime = {}
        
            anime['MAL_ID'] = [anime_id]
            anime['Name'] = [anime_json_data['data'].get('title')]
            anime['English_name'] = [anime_json_data['data'].get('title_english')]
            anime['Japanese_name'] = [anime_json_data['data'].get('title_japanese')]
            anime['Score'] = [anime_json_data['data'].get('score')]
            anime['Type'] = [anime_json_data['data'].get('type')]
            anime['Episodes'] = [anime_json_data['data'].get('episodes')]
            anime['Aired'] = [anime_json_data['data'].get('aired', {}).get('string')]
        
            premiered = anime_json_data['data'].get('season')
            year = anime_json_data['data'].get('year')
            if year is not None: premiered += ' ' + str(year)
            anime['Premiered'] = [premiered]
        
            anime['Status'] = [anime_json_data['data'].get('status')]
            anime['Producers'] = [', '.join([producer['name'] for producer in anime_json_data['data'].get('producers', [])])]
            anime['Licensors'] = [', '.join([license['name'] for license in anime_json_data['data'].get('licensors', [])])]
            anime['Studios'] = [', '.join([studio['name'] for studio in anime_json_data['data'].get('studios', [])])]
            anime['Source'] = [anime_json_data['data'].get('source')]
            anime['Duration'] = [anime_json_data['data'].get('duration')]
            anime['Rating'] = [anime_json_data['data'].get('rating')]
            anime['Rank'] = [anime_json_data['data'].get('rank')]
            anime['Popularity'] = [anime_json_data['data'].get('popularity')]
            anime['Favorites'] = [anime_json_data['data'].get('favorites')]
            anime['Members'] = [anime_json_data['data'].get('members')]
            anime['Watching'] = [statistics_json_data['data'].get('watching')]
            anime['Completed'] = [statistics_json_data['data'].get('completed')]
            anime['On_hold'] = [statistics_json_data['data'].get('on_hold')]
            anime['Dropped'] = [statistics_json_data['data'].get('dropped')]
            anime['Plan_to_watch'] = [statistics_json_data['data'].get('plan_to_watch')]
            
            anime['Scored_by'] = [anime_json_data['data'].get('scored_by')]
            anime['Score_1'] = [statistics_json_data['data'].get('scores')[0].get('votes')]
            anime['Score_2'] = [statistics_json_data['data'].get('scores')[1].get('votes')]
            anime['Score_3'] = [statistics_json_data['data'].get('scores')[2].get('votes')]
            anime['Score_4'] = [statistics_json_data['data'].get('scores')[3].get('votes')]
            anime['Score_5'] = [statistics_json_data['data'].get('scores')[4].get('votes')]
            anime['Score_6'] = [statistics_json_data['data'].get('scores')[5].get('votes')]
            anime['Score_7'] = [statistics_json_data['data'].get('scores')[6].get('votes')]
            anime['Score_8'] = [statistics_json_data['data'].get('scores')[7].get('votes')]
            anime['Score_9'] = [statistics_json_data['data'].get('scores')[8].get('votes')]
            anime['Score_10'] = [statistics_json_data['data'].get('scores')[9].get('votes')]
        
            anime_df = pd.DataFrame.from_dict(anime)
            full_anime_df = pd.concat([full_anime_df, anime_df])
            
        # if 'data' property is not present, the anime id is skipped
        else: print('Skipping anime {}: Invalid data'.format(anime_id))
        
    # if the requisition fails 'TRIES_LIMIT' times to fetch the data, the anime id is skipped
    else: print('Skipping anime {}: Not existent'.format(anime_id))

print('Finished fetching animes.')
# Out:
# Skipping anime 0: Invalid data
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_4768\165445239.py:83: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_anime_df = pd.concat([full_anime_df, anime_df])
# Skipping anime 2: Not existent
# Skipping anime 3: Not existent
# Skipping anime 4: Not existent
# Skipping anime 9: Not existent
# Skipping anime 10: Not existent
# Skipping anime 11: Not existent
# Skipping anime 12: Not existent
# Skipping anime 13: Not existent
# Skipping anime 14: Not existent
# Skipping anime 34: Not existent
# Skipping anime 35: Not existent
# Skipping anime 36: Not existent
# Skipping anime 37: Not existent
# Skipping anime 38: Not existent
# Skipping anime 39: Not existent
# Skipping anime 40: Not existent
# Skipping anime 41: Not existent
# Skipping anime 42: Not existent
# Skipping anime 70: Not existent
# Skipping anime 78: Not existent
# Skipping anime 140: Not existent
# Skipping anime 172: Not existent
# Finished fetching animes.

# %%
# ---- Transforming Datas for Better CSV Exportation ----
full_anime_df.set_index('MAL_ID', inplace=True)
full_anime_df['Name'] = full_anime_df['Name'].str.replace(';', ' ')
full_anime_df['English_name'] = full_anime_df['English_name'].str.replace(';', ' ')
full_anime_df['Japanese_name'] = full_anime_df['Japanese_name'].str.replace(';', ' ')
full_anime_df
# Out:
#                                    Name             English_name  \
# MAL_ID
# 1                          Cowboy Bebop             Cowboy Bebop
# 5       Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 6                                Trigun                   Trigun
# 7                    Witch Hunter Robin       Witch Hunter Robin
# 8                        Bouken Ou Beet   Beet the Vandel Buster
# ...                                 ...                      ...
# 195                      Onegai☆Teacher          Please Teacher!
# 196                        Onegai☆Twins            Please Twins!
# 197                           Rizelmine                     None
# 198                       Speed Grapher            Speed Grapher
# 199       Sen to Chihiro no Kamikakushi            Spirited Away
#
#                            Japanese_name  Score   Type Episodes  \
# MAL_ID
# 1                              カウボーイビバップ   8.75     TV       26
# 5                         カウボーイビバップ 天国の扉   8.38  Movie        1
# 6                                  トライガン   8.22     TV       26
# 7       Witch Hunter ROBIN (ウイッチハンターロビン)   7.24     TV       26
# 8                                 冒険王ビィト   6.93     TV       52
# ...                                  ...    ...    ...      ...
# 195                          おねがい☆ティーチャー   7.10     TV       12
# 196                            おねがい☆ツインズ   6.81     TV       12
# 197                               りぜるまいん   6.50     TV       24
# 198                            スピードグラファー   7.30     TV       24
# 199                             千と千尋の神隠し   8.77  Movie        1
#
#                                Aired    Premiered           Status  \
# MAL_ID
# 1        Apr 3, 1998 to Apr 24, 1999  spring 1998  Finished Airing
# 5                        Sep 1, 2001         None  Finished Airing
# 6        Apr 1, 1998 to Sep 30, 1998  spring 1998  Finished Airing
# 7        Jul 3, 2002 to Dec 25, 2002  summer 2002  Finished Airing
# 8       Sep 30, 2004 to Sep 29, 2005    fall 2004  Finished Airing
# ...                              ...          ...              ...
# 195     Jan 10, 2002 to Mar 28, 2002  winter 2002  Finished Airing
# 196     Jul 15, 2003 to Oct 14, 2003  summer 2003  Finished Airing
# 197      Apr 3, 2002 to Dec 22, 2002  spring 2002  Finished Airing
# 198      Apr 8, 2005 to Sep 30, 2005  spring 2005  Finished Airing
# 199                     Jul 20, 2001         None  Finished Airing
#
#                                                 Producers  \
# MAL_ID
# 1                                           Bandai Visual
# 5                                  Sunrise, Bandai Visual
# 6                                    Victor Entertainment
# 7       Bandai Visual, Dentsu, Victor Entertainment, T...
# 8                                        TV Tokyo, Dentsu
# ...                                                   ...
# 195                                  Bandai Visual, Genco
# 196                          Bandai Visual, Genco, Lantis
# 197                                                m.o.e.
# 198                              TV Asahi, WAO World, TAP
# 199     Dentsu, TOHO, Tokuma Shoten, Tohokushinsha Fil...
#
#                                          Licensors           Studios  \
# MAL_ID
# 1                                       Funimation           Sunrise
# 5          Sony Pictures Entertainment, Funimation             Bones
# 6                                       Funimation          Madhouse
# 7                 Funimation, Bandai Entertainment           Sunrise
# 8                         Illumitoon Entertainment    Toei Animation
# ...                                            ...               ...
# 195     Nozomi Entertainment, Bandai Entertainment             Daume
# 196     Nozomi Entertainment, Bandai Entertainment             Daume
# 197                                                 Madhouse, Imagin
# 198                                     Funimation             Gonzo
# 199            Disney Platform Distribution, GKIDS     Studio Ghibli
#
#           Source       Duration                          Rating  Rank  \
# MAL_ID
# 1       Original  24 min per ep  R - 17+ (violence & profanity)    46
# 5       Original    1 hr 55 min  R - 17+ (violence & profanity)   198
# 6          Manga  24 min per ep       PG-13 - Teens 13 or older   344
# 7       Original  25 min per ep       PG-13 - Teens 13 or older  3022
# 8          Manga  23 min per ep                   PG - Children  4506
# ...          ...            ...                             ...   ...
# 195     Original  22 min per ep       PG-13 - Teens 13 or older  3749
# 196     Original  23 min per ep       PG-13 - Teens 13 or older  5066
# 197        Manga  15 min per ep                R+ - Mild Nudity  6801
# 198     Original  23 min per ep                R+ - Mild Nudity  2714
# 199     Original     2 hr 4 min                   PG - Children    39
#
#        Popularity Favorites  Members Watching Completed On_hold Dropped  \
# MAL_ID
# 1              43     82686  1871594   173523   1081861  107126   43450
# 5             619      1591   379634     7105    280971    3006    1214
# 6             253     16069   765871    46623    449235   33671   18867
# 7            1862       649   117272     5738     52819    5970    6252
# 8            5350        15    15774      836      8561     838    1242
# ...           ...       ...      ...      ...       ...     ...     ...
# 195          1349       974   177889     5499    127105    3305    5091
# 196          2237       189    90194     2481     67650    1722    2488
# 197          4387        49    25718     1233     13902    1098    1874
# 198          1894       602   115021     6296     47946    5529    5763
# 199            44     32972  1859771    25653   1681280    4748    2197
#
#        Plan_to_watch Scored_by Score_1 Score_2 Score_3 Score_4 Score_5  \
# MAL_ID
# 1             465634    968293    2304    1128    2017    5024   13706
# 5              87399    216227     455     148     301     770    2553
# 6             217475    374435     645     415     925    2560    7686
# 7              46501     44216     176     196     412    1233    3319
# 8               4298      6843      57      52      95     288     718
# ...              ...       ...     ...     ...     ...     ...     ...
# 195            36897     95886     579     821    1432    3523    8411
# 196            15853     50281     346     521     951    2341    5320
# 197             7613     10944     172     231     339     706    1508
# 198            49480     41560     230     325     474    1278    2909
# 199           145718   1302990    1838     921    1522    4049   12490
#
#        Score_6 Score_7 Score_8 Score_9 Score_10
# MAL_ID
# 1        32556   97619  204868  273401   335670
# 5         7917   30890   67993   64569    40659
# 6        20453   65951  114649   96382    64769
# 7         6628   13188   11106    5210     2748
# 8         1208    1884    1326     808      407
# ...        ...     ...     ...     ...      ...
# 195      15545   26430   20583   10702     7864
# 196       9692   14339    9413    4518     2840
# 197       2269    2713    1636     829      541
# 198       5642   11275   10813    5437     3175
# 199      35912  122253  284145  376149   463597
#
# [177 rows x 35 columns]

# %%
# ---- Storing Dataset into Disk ----
full_anime_df.to_csv(f'{DATASETS_PATH}/anime.csv')

# %% [markdown]
# ### Anime With Synopsis

# %%
# ---- Dataset Structure ----
header = [
    'MAL_ID', 'Name', 'Score', 'Genres', 'synopsis', 'Rank'
]
full_anime_df = pd.DataFrame(columns=header)
full_anime_df

# ---- API Requisitions ----
for anime_id in ANIME_IDS:
    anime_api_url = f'https://api.jikan.moe/v4/anime/{anime_id}'
    statistics_api_url = f'https://api.jikan.moe/v4/anime/{anime_id}/statistics'
    anime_page = None
    statistics_page = None

    tries = 0
    while tries < TRIES_LIMIT:
        tries += 1
        anime_page = requests.get(anime_api_url)
        statistics_page = requests.get(statistics_api_url)
        
        if anime_page.status_code == 200 and statistics_page.status_code == 200: break
        time.sleep(2)
    
    # if the requisition successfully returned the anime data, it will be processed
    if anime_page.status_code == 200 and statistics_page.status_code == 200:
        anime_json_data = anime_page.json()
        statistics_json_data = statistics_page.json()
    
        # if 'data' property is present, it's formatted and inserted into the dataset
        if 'data' in anime_json_data and 'data' in statistics_json_data:
            anime = {}
        
            anime['MAL_ID'] = [anime_id]
            anime['Name'] = [anime_json_data['data'].get('title')]
            anime['Score'] = [anime_json_data['data'].get('score')]
            anime['Rank'] = [anime_json_data['data'].get('rank')]
            anime['Genres']  = [', '.join([genre['name'] for genre in anime_json_data['data'].get('genres', [])])]
        
            synopsis =  anime_json_data['data'].get('synopsis')
            if synopsis is not None:
                cleared_synopsis = re.sub(r'\[.*?\]', '', synopsis).strip() # removing all text into brackets and the brackets itself
                anime['synopsis'] = [cleared_synopsis]
            else:
                anime['synopsis'] = ['']
                
            anime_df = pd.DataFrame.from_dict(anime)
            full_anime_df = pd.concat([full_anime_df, anime_df])
            
        # if 'data' property is not present, the anime id is skipped
        else: print('Skipping anime {}: Invalid data'.format(anime_id))
        
    # if the requisition fails 'TRIES_LIMIT' times to fetch the data, the anime id is skipped
    else: print('Skipping anime {}: Not existent'.format(anime_id))

print('Finished fetching animes.')
# Out:
# Skipping anime 0: Invalid data
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_4768\1358444346.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_anime_df = pd.concat([full_anime_df, anime_df])
# Skipping anime 2: Not existent
# Skipping anime 3: Not existent
# Skipping anime 4: Not existent
# Skipping anime 9: Not existent
# Skipping anime 10: Not existent
# Skipping anime 11: Not existent
# Skipping anime 12: Not existent
# Skipping anime 13: Not existent
# Skipping anime 14: Not existent
# Skipping anime 34: Not existent
# Skipping anime 35: Not existent
# Skipping anime 36: Not existent
# Skipping anime 37: Not existent
# Skipping anime 38: Not existent
# Skipping anime 39: Not existent
# Skipping anime 40: Not existent
# Skipping anime 41: Not existent
# Skipping anime 42: Not existent
# Skipping anime 70: Not existent
# Skipping anime 78: Not existent
# Skipping anime 140: Not existent
# Skipping anime 172: Not existent
# Finished fetching animes.

# %%
# ---- Transforming Datas for Better CSV Exportation ----
full_anime_df.set_index('MAL_ID', inplace=True)
full_anime_df['Name'] = full_anime_df['Name'].str.replace(';', ' ')
full_anime_df
# Out:
#                                    Name  Score  \
# MAL_ID
# 1                          Cowboy Bebop   8.75
# 5       Cowboy Bebop: Tengoku no Tobira   8.38
# 6                                Trigun   8.22
# 7                    Witch Hunter Robin   7.24
# 8                        Bouken Ou Beet   6.93
# ...                                 ...    ...
# 195                      Onegai☆Teacher   7.10
# 196                        Onegai☆Twins   6.81
# 197                           Rizelmine   6.50
# 198                       Speed Grapher   7.30
# 199       Sen to Chihiro no Kamikakushi   8.77
#
#                                         Genres  \
# MAL_ID
# 1                Action, Award Winning, Sci-Fi
# 5                               Action, Sci-Fi
# 6                    Action, Adventure, Sci-Fi
# 7         Action, Drama, Mystery, Supernatural
# 8                   Action, Adventure, Fantasy
# ...                                        ...
# 195                     Drama, Romance, Sci-Fi
# 196                      Comedy, Drama, Sci-Fi
# 197             Comedy, Romance, Sci-Fi, Ecchi
# 198              Action, Mystery, Supernatural
# 199     Adventure, Award Winning, Supernatural
#
#                                                  synopsis  Rank
# MAL_ID
# 1       Crime is timeless. By the year 2071, humanity ...    46
# 5       Another day, another bounty—such is the life o...   198
# 6       Vash the Stampede is the man with a $$60,000,0...   344
# 7       Robin Sena is a powerful craft user drafted in...  3022
# 8       It is the dark century and the people are suff...  4506
# ...                                                   ...   ...
# 195     One day, Kei Kusanagi notices a strange glowin...  3749
# 196     Maiku Kamishiro's past has always been somewha...  5066
# 197     Iwaki Tomonori is an average 15-year-old boy w...  6801
# 198     Ten years after the Bubble War, the dichotomy ...  2714
# 199     Stubborn, spoiled, and naïve, 10-year-old Chih...    39
#
# [177 rows x 5 columns]

# %%
# ---- Storing Dataset into Disk ----
full_anime_df.to_csv(f'{DATASETS_PATH}/synopsis.csv')

# %% [markdown]
# ### User Data Fetcher

# %%
# ---- Dataset Structure ----
header = ['user_id', 'username', 'url']
full_users_df = pd.DataFrame(columns=header)

# ---- API Requisitions ----
for user_id in USER_IDS:
    user_api_url = f'https://api.jikan.moe/v4/users/userbyid/{user_id}'
    user_page = None
    
    tries = 0
    while tries < TRIES_LIMIT:
        tries += 1
        user_page = requests.get(user_api_url)
        if user_page.status_code == 200: break
        time.sleep(1)
    
    # if the requisition successfully returned the user data, it's processed
    if user_page.status_code == 200:
        user_json_data = user_page.json()
        
        # if 'data' property is present, it's formatted and inserted into the dataset
        if 'data' in user_json_data:
            user = {}
            
            user['user_id'] = [user_id]
            user['username'] = [user_json_data['data'].get('username')]
            user['url'] = [user_json_data['data'].get('url')]
            
            user_df = pd.DataFrame.from_dict(user)
            full_users_df = pd.concat([full_users_df, user_df])
        
        # if 'data' property is not present, the user id is skipped
        else: print('Skipping user {}: Invalid data.'.format(user_id))
    
    # if the requisition fails 'TRIES_LIMIT' times to fetch the data, the user id is skipped
    else: print('Skipping user {}: Not existent.'.format(user_id))

print('Finished fetching users.')
# Out:
# Skipping user 0: Invalid data.
# Skipping user 2: Not existent.
# Skipping user 5: Not existent.
# Skipping user 6: Not existent.
# Skipping user 7: Not existent.
# Skipping user 8: Not existent.
# Skipping user 10: Not existent.
# Skipping user 11: Not existent.
# Skipping user 12: Not existent.
# Skipping user 13: Not existent.
# Skipping user 14: Not existent.
# Skipping user 15: Not existent.
# Skipping user 16: Not existent.
# Skipping user 17: Not existent.
# Skipping user 19: Not existent.
# Skipping user 21: Not existent.
# Skipping user 22: Not existent.
# Skipping user 24: Not existent.
# Skipping user 25: Not existent.
# Skipping user 26: Not existent.
# Skipping user 27: Not existent.
# Skipping user 28: Not existent.
# Skipping user 29: Not existent.
# Skipping user 30: Not existent.
# Skipping user 31: Not existent.
# Skipping user 32: Not existent.
# Skipping user 33: Not existent.
# Skipping user 34: Not existent.
# Skipping user 35: Not existent.
# Skipping user 38: Not existent.
# Skipping user 39: Not existent.
# Skipping user 40: Not existent.
# Skipping user 41: Not existent.
# Skipping user 42: Not existent.
# Skipping user 43: Not existent.
# Skipping user 45: Not existent.
# Skipping user 46: Not existent.
# Skipping user 49: Not existent.
# Skipping user 50: Not existent.
# Skipping user 51: Not existent.
# Skipping user 52: Not existent.
# Skipping user 54: Not existent.
# Skipping user 55: Not existent.
# Skipping user 56: Not existent.
# Skipping user 57: Not existent.
# Skipping user 58: Not existent.
# Skipping user 59: Not existent.
# Skipping user 60: Not existent.
# Skipping user 61: Not existent.
# Skipping user 62: Not existent.
# Skipping user 63: Not existent.
# Skipping user 64: Not existent.
# Skipping user 65: Not existent.
# Skipping user 68: Not existent.
# Skipping user 69: Not existent.
# Skipping user 73: Not existent.
# Skipping user 74: Not existent.
# Skipping user 75: Not existent.
# Skipping user 76: Not existent.
# Skipping user 78: Not existent.
# Skipping user 79: Not existent.
# Skipping user 84: Not existent.
# Skipping user 85: Not existent.
# Skipping user 86: Not existent.
# Skipping user 87: Not existent.
# Skipping user 89: Not existent.
# Skipping user 92: Not existent.
# Skipping user 93: Not existent.
# Skipping user 94: Not existent.
# Skipping user 96: Not existent.
# Skipping user 97: Not existent.
# Skipping user 98: Not existent.
# Skipping user 99: Not existent.
# Skipping user 100: Not existent.
# Skipping user 101: Not existent.
# Skipping user 102: Not existent.
# Skipping user 103: Not existent.
# Skipping user 104: Not existent.
# Skipping user 105: Not existent.
# Skipping user 106: Not existent.
# Skipping user 107: Not existent.
# Skipping user 109: Not existent.
# Skipping user 113: Not existent.
# Skipping user 115: Not existent.
# Skipping user 117: Not existent.
# Skipping user 118: Not existent.
# Skipping user 121: Not existent.
# Skipping user 122: Not existent.
# Skipping user 125: Not existent.
# Skipping user 126: Not existent.
# Skipping user 127: Not existent.
# Skipping user 128: Not existent.
# Skipping user 129: Not existent.
# Skipping user 131: Not existent.
# Skipping user 132: Not existent.
# Skipping user 134: Not existent.
# Skipping user 135: Not existent.
# Skipping user 136: Not existent.
# Skipping user 137: Not existent.
# Skipping user 139: Not existent.
# Skipping user 140: Not existent.
# Skipping user 141: Not existent.
# Skipping user 142: Not existent.
# Skipping user 144: Not existent.
# Skipping user 145: Not existent.
# Skipping user 146: Not existent.
# Skipping user 147: Not existent.
# Skipping user 148: Not existent.
# Skipping user 149: Not existent.
# Skipping user 150: Not existent.
# Skipping user 151: Not existent.
# Skipping user 152: Not existent.
# Skipping user 153: Not existent.
# Skipping user 155: Not existent.
# Skipping user 156: Not existent.
# Skipping user 158: Not existent.
# Skipping user 159: Not existent.
# Skipping user 160: Not existent.
# Skipping user 161: Not existent.
# Skipping user 164: Not existent.
# Skipping user 165: Not existent.
# Skipping user 166: Not existent.
# Skipping user 167: Not existent.
# Skipping user 168: Not existent.
# Skipping user 171: Not existent.
# Skipping user 172: Not existent.
# Skipping user 173: Not existent.
# Skipping user 174: Not existent.
# Skipping user 175: Not existent.
# Skipping user 176: Not existent.
# Skipping user 177: Not existent.
# Skipping user 179: Not existent.
# Skipping user 180: Not existent.
# Skipping user 181: Not existent.
# Skipping user 182: Not existent.
# Skipping user 183: Not existent.
# Skipping user 184: Not existent.
# Skipping user 186: Not existent.
# Skipping user 187: Not existent.
# Skipping user 188: Not existent.
# Skipping user 189: Not existent.
# Skipping user 190: Not existent.
# Skipping user 191: Not existent.
# Skipping user 192: Not existent.
# Skipping user 193: Not existent.
# Skipping user 194: Not existent.
# Skipping user 195: Not existent.
# Skipping user 196: Not existent.
# Skipping user 198: Not existent.
# Skipping user 199: Not existent.
# Finished fetching users.

# %%
# ---- Transforming Datas for Better CSV Exportation ----
full_users_df.set_index('user_id', inplace=True)
full_users_df
# Out:
#                  username                                               url
# user_id
# 1                   Xinil             https://myanimelist.net/profile/Xinil
# 3                 Aokaado           https://myanimelist.net/profile/Aokaado
# 4                 Crystal           https://myanimelist.net/profile/Crystal
# 9                  Arcane            https://myanimelist.net/profile/Arcane
# 18                    Mad               https://myanimelist.net/profile/Mad
# 20                 vondur            https://myanimelist.net/profile/vondur
# 23                  Amuro             https://myanimelist.net/profile/Amuro
# 36                  Baman             https://myanimelist.net/profile/Baman
# 37                  megan             https://myanimelist.net/profile/megan
# 44                 beddan            https://myanimelist.net/profile/beddan
# 47              kei-clone         https://myanimelist.net/profile/kei-clone
# 48                   seif              https://myanimelist.net/profile/seif
# 53             Ladholyman        https://myanimelist.net/profile/Ladholyman
# 66                 Hiromi            https://myanimelist.net/profile/Hiromi
# 67               ShadowOz          https://myanimelist.net/profile/ShadowOz
# 70                 Cruzle            https://myanimelist.net/profile/Cruzle
# 71                  Smoka             https://myanimelist.net/profile/Smoka
# 72                james2k           https://myanimelist.net/profile/james2k
# 77                    Emp               https://myanimelist.net/profile/Emp
# 80              koalatees         https://myanimelist.net/profile/koalatees
# 81                   Ramp              https://myanimelist.net/profile/Ramp
# 82                 Achtor            https://myanimelist.net/profile/Achtor
# 83                 jaames            https://myanimelist.net/profile/jaames
# 88               wicked2k          https://myanimelist.net/profile/wicked2k
# 90                   xich              https://myanimelist.net/profile/xich
# 91        marvin_9martian   https://myanimelist.net/profile/marvin_9martian
# 95                sorairo           https://myanimelist.net/profile/sorairo
# 108              Keitarou          https://myanimelist.net/profile/Keitarou
# 110      happykawaiibunny  https://myanimelist.net/profile/happykawaiibunny
# 111                Misato            https://myanimelist.net/profile/Misato
# 112              luffykun          https://myanimelist.net/profile/luffykun
# 114                bluecc            https://myanimelist.net/profile/bluecc
# 116                 loklo             https://myanimelist.net/profile/loklo
# 119                Phony2            https://myanimelist.net/profile/Phony2
# 120                 hazte             https://myanimelist.net/profile/hazte
# 123              Davidoff          https://myanimelist.net/profile/Davidoff
# 124              Torstein          https://myanimelist.net/profile/Torstein
# 130               Ezzpify           https://myanimelist.net/profile/Ezzpify
# 133               Ritsuka           https://myanimelist.net/profile/Ritsuka
# 138           DanskiJonez       https://myanimelist.net/profile/DanskiJonez
# 143                 Rukia             https://myanimelist.net/profile/Rukia
# 154               bakavic           https://myanimelist.net/profile/bakavic
# 157              KobaKoba          https://myanimelist.net/profile/KobaKoba
# 162                Sigyns            https://myanimelist.net/profile/Sigyns
# 163                 Holzy             https://myanimelist.net/profile/Holzy
# 169           Nekokitsune       https://myanimelist.net/profile/Nekokitsune
# 170                  Klld              https://myanimelist.net/profile/Klld
# 178            1234567890        https://myanimelist.net/profile/1234567890
# 185                 Fador             https://myanimelist.net/profile/Fador
# 197               Yuurei_           https://myanimelist.net/profile/Yuurei_

# %%
# ---- Storing Dataset into Disk ----
full_users_df.to_csv(f'{DATASETS_PATH}/users.csv')
